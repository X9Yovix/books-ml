# %%
print(" Project: Books Recommendation using item based collaborative filtering " )
# Out:
#  Project: Books Recommendation using item based collaborative filtering

# %%
print(" Epic 1 - load, clean - data cleaning and preparation " )
# Out:
#  Epic 1 - load, clean - data cleaning and preparation

# %%
# dependecies
print(" --------- Step 1 --------- ")

## E1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

## E3
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

## E4
import pickle
# Out:
#  --------- Step 1 ---------

# %%
# load ds books
print(" --------- Step 2 --------- ")

books = pd.read_csv(
    "./dataset/BX-Books.csv",
    sep=";",
    on_bad_lines="skip",
    encoding="latin-1",
    dtype={
        "ISBN": str,
        "Book-Title": str,
        "Book-Author": str,
        "Year-Of-Publication": str,
        "Publisher": str,
        "Image-URL-S": str,
        "Image-URL-M": str,
        "Image-URL-L": str
    }
)

# row, col
print(books.shape)
print("\n")
display(books.head(4))
print("\n")
print(books["Year-Of-Publication"].unique())
# Out:
#  --------- Step 2 ---------
# (271360, 8)
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
#
#             Book-Author Year-Of-Publication                Publisher  \
# 0    Mark P. O. Morford                2002  Oxford University Press
# 1  Richard Bruce Wright                2001    HarperFlamingo Canada
# 2          Carlo D'Este                1991          HarperPerennial
# 3      Gina Bari Kolata                1999     Farrar Straus Giroux
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# ['2002' '2001' '1991' '1999' '2000' '1993' '1996' '1988' '2004' '1998'
#  '1994' '2003' '1997' '1983' '1979' '1995' '1982' '1985' '1992' '1986'
#  '1978' '1980' '1952' '1987' '1990' '1981' '1989' '1984' '0' '1968' '1961'
#  '1958' '1974' '1976' '1971' '1977' '1975' '1965' '1941' '1970' '1962'
#  '1973' '1972' '1960' '1966' '1920' '1956' '1959' '1953' '1951' '1942'
#  '1963' '1964' '1969' '1954' '1950' '1967' '2005' '1957' '1940' '1937'
#  '1955' '1946' '1936' '1930' '2011' '1925' '1948' '1943' '1947' '1945'
#  '1923' '2020' '1939' '1926' '1938' '2030' '1911' '1904' '1949' '1932'
#  '1928' '1929' '1927' '1931' '1914' '2050' '1934' '1910' '1933' '1902'
#  '1924' '1921' '1900' '2038' '2026' '1944' '1917' '1901' '2010' '1908'
#  '1906' '1935' '1806' '2021' '2012' '2006' 'DK Publishing Inc' 'Gallimard'
#  '1909' '2008' '1378' '1919' '1922' '1897' '2024' '1376' '2037']

# %%
# clean ds
# clean Year-Of-Publication column
print(" --------- Step 3 --------- ")
print('\n')

print(" --------- invalid values -> NaN /clear strings --------- ")
books["Year-Of-Publication"] = pd.to_numeric(books["Year-Of-Publication"], errors="coerce")
print(books["Year-Of-Publication"].unique())
print('\n')

print(" --------- outof range -> NaN  --------- ")
books.loc[(books["Year-Of-Publication"] < 1900) | (books["Year-Of-Publication"] > 2024), "Year-Of-Publication"] = pd.NA
print(books["Year-Of-Publication"].unique())
print('\n')

# assign 'Unknown' to missing values 
books["Year-Of-Publication"] = books["Year-Of-Publication"].astype("object")
books["Year-Of-Publication"] = books["Year-Of-Publication"].fillna("Unknown")


# convert the years to integers
books["Year-Of-Publication"] = books["Year-Of-Publication"].apply(lambda x: str(int(x)) if x != "Unknown" else x)

print("books['Year-Of-Publication'].unique():")
print(books["Year-Of-Publication"].unique())
print('\n')
# Out:
#  --------- Step 3 ---------
#
#
#  --------- invalid values -> NaN /clear strings ---------
# [2002. 2001. 1991. 1999. 2000. 1993. 1996. 1988. 2004. 1998. 1994. 2003.
#  1997. 1983. 1979. 1995. 1982. 1985. 1992. 1986. 1978. 1980. 1952. 1987.
#  1990. 1981. 1989. 1984.    0. 1968. 1961. 1958. 1974. 1976. 1971. 1977.
#  1975. 1965. 1941. 1970. 1962. 1973. 1972. 1960. 1966. 1920. 1956. 1959.
#  1953. 1951. 1942. 1963. 1964. 1969. 1954. 1950. 1967. 2005. 1957. 1940.
#  1937. 1955. 1946. 1936. 1930. 2011. 1925. 1948. 1943. 1947. 1945. 1923.
#  2020. 1939. 1926. 1938. 2030. 1911. 1904. 1949. 1932. 1928. 1929. 1927.
#  1931. 1914. 2050. 1934. 1910. 1933. 1902. 1924. 1921. 1900. 2038. 2026.
#  1944. 1917. 1901. 2010. 1908. 1906. 1935. 1806. 2021. 2012. 2006.   nan
#  1909. 2008. 1378. 1919. 1922. 1897. 2024. 1376. 2037.]
#
#
#  --------- outof range -> NaN  ---------
# [2002. 2001. 1991. 1999. 2000. 1993. 1996. 1988. 2004. 1998. 1994. 2003.
#  1997. 1983. 1979. 1995. 1982. 1985. 1992. 1986. 1978. 1980. 1952. 1987.
#  1990. 1981. 1989. 1984.   nan 1968. 1961. 1958. 1974. 1976. 1971. 1977.
#  1975. 1965. 1941. 1970. 1962. 1973. 1972. 1960. 1966. 1920. 1956. 1959.
#  1953. 1951. 1942. 1963. 1964. 1969. 1954. 1950. 1967. 2005. 1957. 1940.
#  1937. 1955. 1946. 1936. 1930. 2011. 1925. 1948. 1943. 1947. 1945. 1923.
#  2020. 1939. 1926. 1938. 1911. 1904. 1949. 1932. 1928. 1929. 1927. 1931.
#  1914. 1934. 1910. 1933. 1902. 1924. 1921. 1900. 1944. 1917. 1901. 2010.
#  1908. 1906. 1935. 2021. 2012. 2006. 1909. 2008. 1919. 1922. 2024.]
#
#
# books['Year-Of-Publication'].unique():
# ['2002' '2001' '1991' '1999' '2000' '1993' '1996' '1988' '2004' '1998'
#  '1994' '2003' '1997' '1983' '1979' '1995' '1982' '1985' '1992' '1986'
#  '1978' '1980' '1952' '1987' '1990' '1981' '1989' '1984' 'Unknown' '1968'
#  '1961' '1958' '1974' '1976' '1971' '1977' '1975' '1965' '1941' '1970'
#  '1962' '1973' '1972' '1960' '1966' '1920' '1956' '1959' '1953' '1951'
#  '1942' '1963' '1964' '1969' '1954' '1950' '1967' '2005' '1957' '1940'
#  '1937' '1955' '1946' '1936' '1930' '2011' '1925' '1948' '1943' '1947'
#  '1945' '1923' '2020' '1939' '1926' '1938' '1911' '1904' '1949' '1932'
#  '1928' '1929' '1927' '1931' '1914' '1934' '1910' '1933' '1902' '1924'
#  '1921' '1900' '1944' '1917' '1901' '2010' '1908' '1906' '1935' '2021'
#  '2012' '2006' '1909' '2008' '1919' '1922' '2024']

# %%
# extract needed and change format
print(" --------- Step 4 --------- ")

print(books.columns)
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher','Image-URL-L']]
print(books.columns)
books.rename(columns= {
    "ISBN": "isbn",
    "Book-Title": "title",
    "Book-Author": "author",
    "Year-Of-Publication": "year",
    "Publisher": "publisher",
    "Image-URL-L": "image_url",
},inplace=True)

print(books.columns)
# Out:
#  --------- Step 4 ---------
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-L'],
#       dtype='object')
# Index(['isbn', 'title', 'author', 'year', 'publisher', 'image_url'], dtype='object')

# %%
# load ds users
print(" --------- Step 5 --------- ")

users = pd.read_csv(
    "./dataset/BX-Users.csv",
    sep=";",
    on_bad_lines="skip",
    encoding="latin-1",
    dtype={
        "User-ID": str,
        "Location": str,
        "Age": "object"
    }
)

# row, col
print(users.shape)
print("\n")
display(users.head(4))
print("\n")
# Out:
#  --------- Step 5 ---------
# (278858, 3)
#   User-ID                         Location  Age
# 0       1               nyc, new york, usa  NaN
# 1       2        stockton, california, usa   18
# 2       3  moscow, yukon territory, russia  NaN
# 3       4        porto, v.n.gaia, portugal   17

# %%
# clean Age column
print(" --------- Step 6 --------- ")
print('\n')

print(" --------- invalid values -> NaN /clear strings --------- ")
users["Age"] = pd.to_numeric(users["Age"], errors="coerce")
print(users["Age"].unique())
print('\n')

# assign 'Unknown' to missing values 
users["Age"] = users["Age"].fillna("Unknown")

# convert Age to integers and filter out unrealistic ages
users["Age"] = users["Age"].apply(
    lambda x: int(x) if isinstance(x, float) and 2 <= x <= 120 else "Unknown"
)

print("users['Age'].unique():")
print(users["Age"].unique())
print('\n')
# Out:
#  --------- Step 6 ---------
#
#
#  --------- invalid values -> NaN /clear strings ---------
# [ nan  18.  17.  61.  26.  14.  25.  19.  46.  55.  32.  24.  20.  34.
#   23.  51.  31.  21.  44.  30.  57.  43.  37.  41.  54.  42.  50.  39.
#   53.  47.  36.  28.  35.  13.  58.  49.  38.  45.  62.  63.  27.  33.
#   29.  66.  40.  15.  60.   0.  79.  22.  16.  65.  59.  48.  72.  56.
#   67.   1.  80.  52.  69.  71.  73.  78.   9.  64. 103. 104.  12.  74.
#   75. 231.   3.  76.  83.  68. 119.  11.  77.   2.  70.  93.   8.   7.
#    4.  81. 114. 230. 239.  10.   5. 148. 151.   6. 101. 201.  96.  84.
#   82.  90. 123. 244. 133.  91. 128.  94.  85. 141. 110.  97. 219.  86.
#  124.  92. 175. 172. 209. 212. 237.  87. 162. 100. 156. 136.  95.  89.
#  106.  99. 108. 210.  88. 199. 147. 168. 132. 159. 186. 152. 102. 116.
#  200. 115. 226. 137. 207. 229. 138. 109. 105. 228. 183. 204.  98. 223.
#  113. 208. 107. 157. 111. 146. 118. 220. 143. 140. 189. 127.]
#
#
# users['Age'].unique():
# ['Unknown' 18 17 61 26 14 25 19 46 55 32 24 20 34 23 51 31 21 44 30 57 43
#  37 41 54 42 50 39 53 47 36 28 35 13 58 49 38 45 62 63 27 33 29 66 40 15
#  60 79 22 16 65 59 48 72 56 67 80 52 69 71 73 78 9 64 103 104 12 74 75 3
#  76 83 68 119 11 77 2 70 93 8 7 4 81 114 10 5 6 101 96 84 82 90 91 94 85
#  110 97 86 92 87 100 95 89 106 99 108 88 102 116 115 109 105 98 113 107
#  111 118]

# %%
# change format
print(" --------- Step 7 --------- ")

print(users.columns)

users.rename(columns={
    "User-ID": "user_id",
    "Location": "location",
    "Age": "age"
}, inplace=True)

print(users.columns)
# Out:
#  --------- Step 7 ---------
# Index(['User-ID', 'Location', 'Age'], dtype='object')
# Index(['user_id', 'location', 'age'], dtype='object')

# %%
# load ds ratings
print(" --------- Step 8 --------- ")

ratings = pd.read_csv(
    "./dataset/BX-Book-Ratings.csv",
    sep=";",
    on_bad_lines="skip",
    encoding="latin-1",
    dtype={
        "User-ID": str,
        "ISBN": str,
        "Book-Rating": str
    }
)

# row, col
print(ratings.shape)
print("\n")
display(ratings.head(8))
print("\n")
# Out:
#  --------- Step 8 ---------
# (1149780, 3)
#   User-ID        ISBN Book-Rating
# 0  276725  034545104X           0
# 1  276726  0155061224           5
# 2  276727  0446520802           0
# 3  276729  052165615X           3
# 4  276729  0521795028           6
# 5  276733  2080674722           0
# 6  276736  3257224281           8
# 7  276737  0600570967           6

# %%
# clean Book-Rating column
print(" --------- Step 9 --------- ")
print('\n')

print(" --------- invalid values -> NaN /clear strings --------- ")
ratings["Book-Rating"] = pd.to_numeric(ratings["Book-Rating"], errors="coerce")
print(ratings["Book-Rating"].unique())
print('\n')

# convert Book-Rating to integers and filter out unrealistic ratings
ratings["Book-Rating"] = ratings["Book-Rating"].apply(
    lambda x: int(x) if 0 <= x <= 10 else pd.NA
)

print("ratings['Book-Rating'].unique():")
print(ratings["Book-Rating"].unique())
print('\n')
# Out:
#  --------- Step 9 ---------
#
#
#  --------- invalid values -> NaN /clear strings ---------
# [ 0  5  3  6  8  7 10  9  4  1  2]
#
#
# ratings['Book-Rating'].unique():
# [ 0  5  3  6  8  7 10  9  4  1  2]

# %%
# change format
print(" --------- Step 10 --------- ")

print(ratings.columns)

ratings.rename(columns={
    "User-ID": "user_id",
    "ISBN": "isbn",
    "Book-Rating": "book_rating"
}, inplace=True)

print(ratings.columns)
# Out:
#  --------- Step 10 ---------
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')
# Index(['user_id', 'isbn', 'book_rating'], dtype='object')

# %%
print(" Epic 2 - filtering and creating our final df - feature engineering " )
# Out:
#  Epic 2 - filtering and creating our final df - feature engineering

# %%
# data preprocessing | ( filter users rated more than 200 and filter based of number of ratings > 50 ) (relevant data, reduces noise, enhances performance) 
print(" --------- Step 11 --------- ")

# users rated more than 200
print(" --------- Step 11 | Part 1 --------- ")

# check how many books each user has rated
ratings['user_id'].value_counts()
# Out:
#  --------- Step 11 ---------
#  --------- Step 11 | Part 1 ---------
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
# users in this df
ratings['user_id'].unique().shape
# Out:
# (105283,)

# %%
x = ratings['user_id'].value_counts() > 200
x
# Out:
# user_id
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: count, Length: 105283, dtype: bool

# %%
# users > 200
x[x].shape
# Out:
# (899,)

# %%
# filter based on index
y = x[x].index
y
# Out:
# Index(['11676', '198711', '153662', '98391', '35859', '212898', '278418',
#        '76352', '110973', '235105',
#        ...
#        '260183', '73681', '44296', '155916', '9856', '274808', '28634',
#        '59727', '268622', '188951'],
#       dtype='object', name='user_id', length=899)

# %%
# filter users rated more than 200
ratings = ratings[ratings['user_id'].isin(y)]
# row, col
ratings.shape
# Out:
# (526356, 3)

# %%
# total number of rating for each title > 50
print(" --------- Step 11 | Part 2 --------- ")
display(books.head(2))
# Out:
#  --------- Step 11 | Part 2 ---------
#          isbn                title                author  year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford  2002
# 1  0002005018         Clara Callan  Richard Bruce Wright  2001
#
#                  publisher                                          image_url
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
display(ratings.head(2))
# Out:
#      user_id        isbn  book_rating
# 1456  277427  002542730X           10
# 1457  277427  0026217457            0

# %%
# merging data
ratings_with_books=ratings.merge(books, on='isbn')
# display(ratings_with_books.head(4))
# verify:
ratings_with_books_sorted = ratings_with_books.sort_values(by='title')
display(ratings_with_books_sorted.head(4))
# Out:
#        user_id        isbn  book_rating  \
# 165535   96448  0590567330            9
# 70253    35859  0590567330            0
# 297750  172742  0964147726            0
# 345423  198711  0942320093            0
#
#                                                     title            author  \
# 165535   A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 70253    A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 297750                              Always Have Popsicles    Rebecca Harvin
# 345423               Apple Magic (The Collector's series)  Martina Boudreau
#
#         year                    publisher  \
# 165535  1999  Hyperion Books for Children
# 70253   1999  Hyperion Books for Children
# 297750  1994            Rebecca L. Harvin
# 345423  1984           Amer Cooking Guild
#
#                                                 image_url
# 165535  http://images.amazon.com/images/P/0590567330.0...
# 70253   http://images.amazon.com/images/P/0590567330.0...
# 297750  http://images.amazon.com/images/P/0964147726.0...
# 345423  http://images.amazon.com/images/P/0942320093.0...

# %%
ratings_with_books.shape
# Out:
# (487671, 8)

# %%
# add a new column that shows the total number of ratings for each title (useful for collaborative filtering)
number_of_ratings = ratings_with_books.groupby('title')['book_rating'].count().reset_index()
display(number_of_ratings)
# Out:
#                                                     title  book_rating
# 0        A Light in the Storm: The Civil War Diary of ...            2
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...            3
# 160265                                      Ã?Â?lpiraten.            1
# 160266                     Ã?Â?rger mit Produkt X. Roman.            1
# 160267                              Ã?Â?stlich der Berge.            1
# 160268                                  Ã?Â?thique en toc            1
#
# [160269 rows x 2 columns]

# %%
number_of_ratings.rename(columns={
    "book_rating": "number_rating",
}, inplace=True)
display(number_of_ratings)
# Out:
#                                                     title  number_rating
# 0        A Light in the Storm: The Civil War Diary of ...              2
# 1                                   Always Have Popsicles              1
# 2                    Apple Magic (The Collector's series)              1
# 3        Beyond IBM: Leadership Marketing and Finance ...              1
# 4        Clifford Visita El Hospital (Clifford El Gran...              1
# ...                                                   ...            ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...              3
# 160265                                      Ã?Â?lpiraten.              1
# 160266                     Ã?Â?rger mit Produkt X. Roman.              1
# 160267                              Ã?Â?stlich der Berge.              1
# 160268                                  Ã?Â?thique en toc              1
#
# [160269 rows x 2 columns]

# %%
# merging data
final_merge = ratings_with_books.merge(number_of_ratings, on='title')
display(final_merge)
# Out:
#        user_id        isbn  book_rating  \
# 0       277427  002542730X           10
# 1       277427  0026217457            0
# 2       277427  003008685X            8
# 3       277427  0030615321            0
# 4       277427  0060002050            0
# ...        ...         ...          ...
# 487666  275970  1931868123            0
# 487667  275970  3411086211           10
# 487668  275970  3829021860            0
# 487669  275970  4770019572            0
# 487670  275970  9626340762            8
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1                      Vegetarian Times Complete Cookbook
# 2                                                Pioneers
# 3        Ask for May, Settle for June (A Doonesbury book)
# 4                       On a Wicked Dawn (Cynster Novels)
# ...                                                   ...
# 487666  There's a Porcupine in My Outhouse: Misadventu...
# 487667                                         Die Biene.
# 487668                                     The Penis Book
# 487669                                            Musashi
# 487670  Northanger Abbey (Classic Literature with Clas...
#
#                                author  year  \
# 0                   James Finn Garner  1994
# 1                          Lucy  Moll  1995
# 2               James Fenimore Cooper  1974
# 3                       G. B. Trudeau  1982
# 4                   Stephanie Laurens  2002
# ...                               ...   ...
# 487666                   Mike Tougias  2002
# 487667  Sybil GrÃ?Â¤fin SchÃ?Â¶nfeldt  1993
# 487668                   Joseph Cohen  1999
# 487669                 Eiji Yoshikawa  1995
# 487670                    Jane Austen  1996
#
#                                    publisher  \
# 0                  John Wiley &amp; Sons Inc
# 1                      John Wiley &amp; Sons
# 2                           Thomson Learning
# 3                        Henry Holt &amp; Co
# 4                                 Avon Books
# ...                                      ...
# 487666                    Capital Books (VA)
# 487667  Bibliographisches Institut, Mannheim
# 487668                              Konemann
# 487669          Kodansha International (JPN)
# 487670                 Naxos Audiobooks Ltd.
#
#                                                 image_url  number_rating
# 0       http://images.amazon.com/images/P/002542730X.0...             82
# 1       http://images.amazon.com/images/P/0026217457.0...              7
# 2       http://images.amazon.com/images/P/003008685X.0...              1
# 3       http://images.amazon.com/images/P/0030615321.0...              1
# 4       http://images.amazon.com/images/P/0060002050.0...             13
# ...                                                   ...            ...
# 487666  http://images.amazon.com/images/P/1931868123.0...              1
# 487667  http://images.amazon.com/images/P/3411086211.0...              1
# 487668  http://images.amazon.com/images/P/3829021860.0...              1
# 487669  http://images.amazon.com/images/P/4770019572.0...              1
# 487670  http://images.amazon.com/images/P/9626340762.0...              2
#
# [487671 rows x 9 columns]

# %%
final_merge.shape
# Out:
# (487671, 9)

# %%
final_rating = final_merge[final_merge['number_rating'] >= 50 ]
display(final_rating)
# Out:
#        user_id        isbn  book_rating  \
# 0       277427  002542730X           10
# 13      277427  0060930535            0
# 15      277427  0060934417            0
# 18      277427  0061009059            9
# 24      277427  006440188X            0
# ...        ...         ...          ...
# 487505  275970  1400031354            0
# 487506  275970  1400031362            0
# 487579  275970  1573229725            0
# 487618  275970  1586210661            9
# 487619  275970  1586212230            0
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 13                          The Poisonwood Bible: A Novel
# 15                                     Bel Canto: A Novel
# 18      One for the Money (Stephanie Plum Novels (Pape...
# 24                                      The Secret Garden
# ...                                                   ...
# 487505  Tears of the Giraffe (No.1 Ladies Detective Ag...
# 487506  Morality for Beautiful Girls (No.1 Ladies Dete...
# 487579                                        Fingersmith
# 487618                             Me Talk Pretty One Day
# 487619                                              Naked
#
#                          author  year                  publisher  \
# 0             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13           Barbara Kingsolver  1999                  Perennial
# 15                 Ann Patchett  2002                  Perennial
# 18              Janet Evanovich  1995                HarperTorch
# 24      Frances Hodgson Burnett  1998               HarperTrophy
# ...                         ...   ...                        ...
# 487505   Alexander McCall Smith  2002                     Anchor
# 487506   Alexander McCall Smith  2002                     Anchor
# 487579             Sarah Waters  2002            Riverhead Books
# 487618            David Sedaris  2001    Time Warner Audio Major
# 487619            David Sedaris  2001    Time Warner Audio Major
#
#                                                 image_url  number_rating
# 0       http://images.amazon.com/images/P/002542730X.0...             82
# 13      http://images.amazon.com/images/P/0060930535.0...            133
# 15      http://images.amazon.com/images/P/0060934417.0...            108
# 18      http://images.amazon.com/images/P/0061009059.0...            108
# 24      http://images.amazon.com/images/P/006440188X.0...             79
# ...                                                   ...            ...
# 487505  http://images.amazon.com/images/P/1400031354.0...             84
# 487506  http://images.amazon.com/images/P/1400031362.0...             60
# 487579  http://images.amazon.com/images/P/1573229725.0...             59
# 487618  http://images.amazon.com/images/P/1586210661.0...            146
# 487619  http://images.amazon.com/images/P/1586212230.0...             53
#
# [61853 rows x 9 columns]

# %%
final_rating.shape
# Out:
# (61853, 9)

# %%
# verify duplicates
print(" --------- Step 12 --------- ")

dummy = final_rating.copy()
dummy['is_duplicate'] = dummy.duplicated(subset=['title', 'user_id'], keep=False)
dummy = dummy.sort_values(by=['user_id', 'title'])

display(dummy.sort_values(by='is_duplicate').tail(20))
#display(dummy.sort_values(by='is_duplicate'))
# Out:
#  --------- Step 12 ---------
#        user_id        isbn  book_rating                                 title  \
# 246783  143175  1586215361            0                            The Jester
# 246156  143175  0316602051            9                            The Jester
# 128412   76151  0440194903            0                   When the Wind Blows
# 128338   76151  0316693324           10                   When the Wind Blows
# 462193  258938  0446676098           10                          The Notebook
# 462188  258938  0446605239           10                          The Notebook
# 246781  143175  1586212869            0                       The Beach House
# 17498    11676  0330332775            0                 Bridget Jones's Diary
# 246392  143175  0446612545            9                       The Beach House
# 298778  173415  067942573X            0  Taltos: Lives of the Mayfair Witches
# 246620  143175  0787120332            9                       Small Town Girl
# 417366  235842  044048474X            0       Tales of a Fourth Grade Nothing
# 417370  235842  0440784743            0       Tales of a Fourth Grade Nothing
# 80005    39281  0060922532            5                        Pigs in Heaven
# 80025    39281  006109868X            0                        Pigs in Heaven
# 246434  143175  051512219X            9                       Small Town Girl
# 246412  143175  0451203771            0                       Scarlet Feather
# 246138  143175  0141803053            0                       Scarlet Feather
# 298453  173415  0345404319            5  Taltos: Lives of the Mayfair Witches
# 329038  190708  0440216745            8                              Whispers
#
#                     author  year                publisher  \
# 246783     James Patterson  2003  Time Warner Audio Major
# 246156     James Patterson  2003            Little, Brown
# 128412           John Saul  1990                     Dell
# 128338     James Patterson  1998            Replica Books
# 462193     Nicholas Sparks  1999             Warner Books
# 462188     Nicholas Sparks  1998             Warner Books
# 246781     James Patterson  2002  Time Warner Audio Major
# 17498       Helen Fielding  1997             Picador (UK)
# 246392     James Patterson  2003             Warner Books
# 298778           Anne Rice  1994          Alfred A. Knopf
# 246620     LaVyrle Spencer  1999         Dove Books Audio
# 417366          JUDY BLUME  1976                 Yearling
# 417370          Judy Blume  1979           Yearling Books
# 80005   Barbara Kingsolver  1994                Perennial
# 80025   Barbara Kingsolver  1999                Perennial
# 246434     Lavyrle Spencer  1998               Jove Books
# 246412        Maeve Binchy  2002              Signet Book
# 246138        Maeve Binchy  2001       Penguin Audiobooks
# 298453           Anne Rice  1996         Ballantine Books
# 329038         BELVA PLAIN  1994                     Dell
#
#                                                 image_url  number_rating  \
# 246783  http://images.amazon.com/images/P/1586215361.0...             68
# 246156  http://images.amazon.com/images/P/0316602051.0...             68
# 128412  http://images.amazon.com/images/P/0440194903.0...            175
# 128338  http://images.amazon.com/images/P/0316693324.0...            175
# 462193  http://images.amazon.com/images/P/0446676098.0...            241
# 462188  http://images.amazon.com/images/P/0446605239.0...            241
# 246781  http://images.amazon.com/images/P/1586212869.0...            142
# 17498   http://images.amazon.com/images/P/0330332775.0...            277
# 246392  http://images.amazon.com/images/P/0446612545.0...            142
# 298778  http://images.amazon.com/images/P/067942573X.0...             53
# 246620  http://images.amazon.com/images/P/0787120332.0...             59
# 417366  http://images.amazon.com/images/P/044048474X.0...             50
# 417370  http://images.amazon.com/images/P/0440784743.0...             50
# 80005   http://images.amazon.com/images/P/0060922532.0...             93
# 80025   http://images.amazon.com/images/P/006109868X.0...             93
# 246434  http://images.amazon.com/images/P/051512219X.0...             59
# 246412  http://images.amazon.com/images/P/0451203771.0...             91
# 246138  http://images.amazon.com/images/P/0141803053.0...             91
# 298453  http://images.amazon.com/images/P/0345404319.0...             53
# 329038  http://images.amazon.com/images/P/0440216745.0...            129
#
#         is_duplicate
# 246783          True
# 246156          True
# 128412          True
# 128338          True
# 462193          True
# 462188          True
# 246781          True
# 17498           True
# 246392          True
# 298778          True
# 246620          True
# 417366          True
# 417370          True
# 80005           True
# 80025           True
# 246434          True
# 246412          True
# 246138          True
# 298453          True
# 329038          True

# %%
final_df=final_rating.drop_duplicates(subset=['title', 'user_id'])

# %%
dummy2 = final_df.copy()
dummy2['is_duplicate'] = dummy2.duplicated(subset=['title', 'user_id'], keep=False)
dummy2 = dummy2.sort_values(by=['title', 'user_id'])
display(dummy2.sort_values(by='is_duplicate'))
# Out:
#        user_id        isbn  book_rating                     title  \
# 182516  104636  0451524934            0                      1984
# 261553  153662  0060096195            0         The Boy Next Door
# 276373  162639  0060096195            0         The Boy Next Door
# 279049  164027  0060096195            7         The Boy Next Door
# 281176  165308  0060096195            0         The Boy Next Door
# ...        ...         ...          ...                       ...
# 155588   91832  0440414806            0  Holes (Yearling Newbery)
# 172481   98741  0440414806            0  Holes (Yearling Newbery)
# 180563  102967  0449702545            8                Homecoming
# 79138    38273  0440414806           10  Holes (Yearling Newbery)
# 156965   92853  0449003787            0       \O\" Is for Outlaw"
#
#                author  year         publisher  \
# 182516  George Orwell  1990       Signet Book
# 261553   Meggin Cabot  2002        Avon Trade
# 276373   Meggin Cabot  2002        Avon Trade
# 279049   Meggin Cabot  2002        Avon Trade
# 281176   Meggin Cabot  2002        Avon Trade
# ...               ...   ...               ...
# 155588   LOUIS SACHAR  2000          Yearling
# 172481   LOUIS SACHAR  2000          Yearling
# 180563  Cynthia Voigt  1990     Fawcett Books
# 79138    LOUIS SACHAR  2000          Yearling
# 156965    SUE GRAFTON  2001  Ballantine Books
#
#                                                 image_url  number_rating  \
# 182516  http://images.amazon.com/images/P/0451524934.0...             76
# 261553  http://images.amazon.com/images/P/0060096195.0...             55
# 276373  http://images.amazon.com/images/P/0060096195.0...             55
# 279049  http://images.amazon.com/images/P/0060096195.0...             55
# 281176  http://images.amazon.com/images/P/0060096195.0...             55
# ...                                                   ...            ...
# 155588  http://images.amazon.com/images/P/0440414806.0...             55
# 172481  http://images.amazon.com/images/P/0440414806.0...             55
# 180563  http://images.amazon.com/images/P/0449702545.0...             61
# 79138   http://images.amazon.com/images/P/0440414806.0...             55
# 156965  http://images.amazon.com/images/P/0449003787.0...            105
#
#         is_duplicate
# 182516         False
# 261553         False
# 276373         False
# 279049         False
# 281176         False
# ...              ...
# 155588         False
# 172481         False
# 180563         False
# 79138          False
# 156965         False
#
# [59850 rows x 10 columns]

# %%
final_df.shape
# Out:
# (59850, 9)

# %%
print(" Epic 3 - preparing data and training Nearest Neighbors Model " )
# Out:
#  Epic 3 - preparing data and training Nearest Neighbors Model

# %%
book_pivot=final_df.pivot_table(columns="user_id", index="title", values="book_rating")
book_pivot
# Out:
# user_id                                             100459  100644  100846  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     8.0
#
# user_id                                             100906  101209  101305  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     NaN     8.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             101851  101876  102275  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     9.0
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             102359  ...  95932  95991  \
# title                                                       ...
# 1984                                                   NaN  ...    NaN    NaN
# 1st to Die: A Novel                                    NaN  ...    NaN    NaN
# 2nd Chance                                             NaN  ...    NaN    NaN
# 4 Blondes                                              NaN  ...    NaN    NaN
# 84 Charing Cross Road                                  NaN  ...    NaN    NaN
# ...                                                    ...  ...    ...    ...
# Year of Wonders                                        NaN  ...    NaN    NaN
# You Belong To Me                                       NaN  ...    NaN    NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...    NaN    NaN
# Zoya                                                   NaN  ...    NaN    NaN
# \O\" Is for Outlaw"                                    NaN  ...    NaN    NaN
#
# user_id                                             96054  96448  97874  \
# title
# 1984                                                  NaN    NaN    NaN
# 1st to Die: A Novel                                   NaN    NaN    NaN
# 2nd Chance                                            NaN    NaN    NaN
# 4 Blondes                                             NaN    NaN    NaN
# 84 Charing Cross Road                                 NaN    NaN    NaN
# ...                                                   ...    ...    ...
# Year of Wonders                                       NaN    NaN    NaN
# You Belong To Me                                      NaN    NaN    NaN
# Zen and the Art of Motorcycle Maintenance: An I...    NaN    NaN    NaN
# Zoya                                                  NaN    NaN    NaN
# \O\" Is for Outlaw"                                   NaN    NaN    NaN
#
# user_id                                             98297  98391  9856  98741  \
# title
# 1984                                                  NaN    NaN   NaN    NaN
# 1st to Die: A Novel                                   NaN    NaN   NaN    NaN
# 2nd Chance                                            NaN    9.0   NaN    NaN
# 4 Blondes                                             NaN    NaN   NaN    NaN
# 84 Charing Cross Road                                 NaN    NaN   NaN    NaN
# ...                                                   ...    ...   ...    ...
# Year of Wonders                                       NaN    NaN   NaN    NaN
# You Belong To Me                                      NaN    NaN   NaN    NaN
# Zen and the Art of Motorcycle Maintenance: An I...    NaN    NaN   NaN    NaN
# Zoya                                                  NaN    NaN   NaN    NaN
# \O\" Is for Outlaw"                                   NaN    NaN   NaN    NaN
#
# user_id                                             98758
# title
# 1984                                                  NaN
# 1st to Die: A Novel                                   NaN
# 2nd Chance                                            NaN
# 4 Blondes                                             NaN
# 84 Charing Cross Road                                 NaN
# ...                                                   ...
# Year of Wonders                                       NaN
# You Belong To Me                                      NaN
# Zen and the Art of Motorcycle Maintenance: An I...    NaN
# Zoya                                                  NaN
# \O\" Is for Outlaw"                                   NaN
#
# [742 rows x 888 columns]

# %%
book_pivot.shape
# Out:
# (742, 888)

# %%
book_pivot.fillna(0, inplace=True)
book_pivot
# Out:
# user_id                                             100459  100644  100846  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     8.0
#
# user_id                                             100906  101209  101305  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     8.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             101851  101876  102275  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     9.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             102359  ...  95932  95991  \
# title                                                       ...
# 1984                                                   0.0  ...    0.0    0.0
# 1st to Die: A Novel                                    0.0  ...    0.0    0.0
# 2nd Chance                                             0.0  ...    0.0    0.0
# 4 Blondes                                              0.0  ...    0.0    0.0
# 84 Charing Cross Road                                  0.0  ...    0.0    0.0
# ...                                                    ...  ...    ...    ...
# Year of Wonders                                        0.0  ...    0.0    0.0
# You Belong To Me                                       0.0  ...    0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...    0.0    0.0
# Zoya                                                   0.0  ...    0.0    0.0
# \O\" Is for Outlaw"                                    0.0  ...    0.0    0.0
#
# user_id                                             96054  96448  97874  \
# title
# 1984                                                  0.0    0.0    0.0
# 1st to Die: A Novel                                   0.0    0.0    0.0
# 2nd Chance                                            0.0    0.0    0.0
# 4 Blondes                                             0.0    0.0    0.0
# 84 Charing Cross Road                                 0.0    0.0    0.0
# ...                                                   ...    ...    ...
# Year of Wonders                                       0.0    0.0    0.0
# You Belong To Me                                      0.0    0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0    0.0    0.0
# Zoya                                                  0.0    0.0    0.0
# \O\" Is for Outlaw"                                   0.0    0.0    0.0
#
# user_id                                             98297  98391  9856  98741  \
# title
# 1984                                                  0.0    0.0   0.0    0.0
# 1st to Die: A Novel                                   0.0    0.0   0.0    0.0
# 2nd Chance                                            0.0    9.0   0.0    0.0
# 4 Blondes                                             0.0    0.0   0.0    0.0
# 84 Charing Cross Road                                 0.0    0.0   0.0    0.0
# ...                                                   ...    ...   ...    ...
# Year of Wonders                                       0.0    0.0   0.0    0.0
# You Belong To Me                                      0.0    0.0   0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0    0.0   0.0    0.0
# Zoya                                                  0.0    0.0   0.0    0.0
# \O\" Is for Outlaw"                                   0.0    0.0   0.0    0.0
#
# user_id                                             98758
# title
# 1984                                                  0.0
# 1st to Die: A Novel                                   0.0
# 2nd Chance                                            0.0
# 4 Blondes                                             0.0
# 84 Charing Cross Road                                 0.0
# ...                                                   ...
# Year of Wonders                                       0.0
# You Belong To Me                                      0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0
# Zoya                                                  0.0
# \O\" Is for Outlaw"                                   0.0
#
# [742 rows x 888 columns]

# %%
# model preparation and training
book_sparse = csr_matrix(book_pivot) # fix prob 0

# %%
model = NearestNeighbors(algorithm="brute")

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
# pre test ( skip, use it after executing the whole code )

# find book to test
# keyword = "kill"
# matching_books = book_pivot.index[books_name.str.contains(keyword, case=False, na=False)]
# display(matching_books)
# Out:
# Index(['A Time to Kill',
#        'K Is for Killer (Kinsey Millhone Mysteries (Paperback))', 'Killjoy',
#        'The Killing Game: Only One Can Win...and the Loser Dies',
#        'To Kill a Mockingbird'],
#       dtype='object', name='title')

# %%
# pre test ( skip )

# find id of book to test
#book_index = book_pivot.index.get_loc('Harry Potter and the Chamber of Secrets (Book 2)')
book_index = np.where(book_pivot.index == 'Harry Potter and the Chamber of Secrets (Book 2)')[0][0]
display(book_index)
# Out:
# 237

# %%
# test 1
distance, suggestion = model.kneighbors(book_pivot.iloc[200,:].values.reshape(1,-1), n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 22.24859546, 22.60530911, 23.43074903, 23.68543856,
#         24.14539294]])

# %%
suggestion
# Out:
# array([[200, 372, 485, 320, 184, 536]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Fatal Cure', 'No Safe Place', 'Table For Two', 'Long After Midnight',
#        'Exclusive', 'The Cradle Will Fall'],
#       dtype='object', name='title')

# %%
# test 2
def recommend_book(name):
    book_id=book_pivot.index.get_loc(name)
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6)
    for i in range(len(suggestion)):
        result=book_pivot.index[suggestion[i]]
        for j in result:
            print(j)

recommend_book('To Kill a Mockingbird')
# Out:
# To Kill a Mockingbird
# Drowning Ruth
# Master of the Game
# Echoes
# Pleading Guilty
# Winter Moon

# %%
# will be used later on
books_name = book_pivot.index
books_name
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=742)

# %%
print(" Epic 4 - Saving model " )
# Out:
#  Epic 4 - Saving model

# %%
pickle.dump(model, open("artifacts/model.pkl", "wb"))
pickle.dump(books_name, open("artifacts/books_name.pkl", "wb"))
pickle.dump(book_pivot, open("artifacts/book_pivot.pkl", "wb"))
pickle.dump(final_df, open("artifacts/final_rating.pkl", "wb"))
